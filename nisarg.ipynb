# %%
import pip

# %%
pip install audio_recorder_streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.2 MB 1.3 MB/s eta 0:00:01
#      - -------------------------------------- 0.1/1.2 MB 656.4 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.2 MB 1.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.2/1.2 MB 1.1 MB/s eta 0:00:01
#      ------- -------------------------------- 0.2/1.2 MB 1.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.2 MB 1.3 MB/s eta 0:00:01
#      ------------ --------------------------- 0.4/1.2 MB 1.2 MB/s eta 0:00:01
#      --------------- ------------------------ 0.5/1.2 MB 1.3 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.5/1.2 MB 1.3 MB/s eta 0:00:01
#      ------------------- -------------------- 0.6/1.2 MB 1.4 MB/s eta 0:00:01
#      --------------------- ------------------ 0.7/1.2 MB 1.4 MB/s eta 0:00:01
# ...

# %%
pip install musixmatch
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for musixmatch: filename=musixmatch-0.9-py3-none-any.whl size=15668 sha256=690542e50f37239112428be695a4b82f38486ff5af880d2a6484db292c7f1e37
#   Stored in directory: c:\users\nisar\appdata\local\pip\cache\wheels\9b\36\c7\7c9bf2eb4089778ff5fe462ecb6f5970eee8efa7d86899b067
# Successfully built musixmatch
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# ...

# %%
pip install protobuf==3.20
# Out:
# ...
#      ---------------------------------------- 0.0/904.1 kB ? eta -:--:--
#      ------- ------------------------------ 184.3/904.1 kB 5.6 MB/s eta 0:00:01
#      ----------------- -------------------- 419.8/904.1 kB 5.3 MB/s eta 0:00:01
#      --------------------------------- ---- 798.7/904.1 kB 6.3 MB/s eta 0:00:01
#      -------------------------------------- 904.1/904.1 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.0
#     Uninstalling protobuf-3.19.0:
#       Successfully uninstalled protobuf-3.19.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# ...

# %%
pip install --upgrade streamlit==1.0.0
# Out:
# ...
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      - -------------------------------------- 0.3/8.3 MB 7.0 MB/s eta 0:00:02
#      -- ------------------------------------- 0.6/8.3 MB 6.4 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.9/8.3 MB 6.2 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.1/8.3 MB 5.8 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/8.3 MB 5.8 MB/s eta 0:00:02
#      ------ --------------------------------- 1.4/8.3 MB 5.4 MB/s eta 0:00:02
#      ------- -------------------------------- 1.6/8.3 MB 4.9 MB/s eta 0:00:02
#      -------- ------------------------------- 1.8/8.3 MB 5.0 MB/s eta 0:00:02
#      --------- ------------------------------ 1.9/8.3 MB 4.9 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.2/8.3 MB 4.9 MB/s eta 0:00:02
#      ----------- ---------------------------- 2.3/8.3 MB 4.8 MB/s eta 0:00:02
# ...

# %%
pip install Musixmatch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# ...

# %%
pip install --upgrade musixmatch
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       1.4.0
# altair                        4.2.0
# anaconda-client               1.11.1
# anaconda-navigator            2.4.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# astor                         0.8.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# attrs                         22.1.0
# audio-recorder-streamlit      0.0.8
# audioread                     3.0.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# base58                        2.1.1
# beautifulsoup4                4.11.1
# bleach                        4.1.0
# blinker                       1.5
# ...

# %%
pip install --upgrade musixmatch==2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement musixmatch==2.0 (from versions: 0.9)
# ERROR: No matching distribution found for musixmatch==2.0
# ...

# %%
pip install musixmatch-py
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for musixmatch-py: filename=musixmatch_py-0.2-py3-none-any.whl size=9623 sha256=6330e96663b5461bfef586f8934dac2ba9fcfec423c154d61b30e922ae64f195
#   Stored in directory: c:\users\nisar\appdata\local\pip\cache\wheels\20\dd\ec\1ff2a539309dc84eadaec4950f4237003869ea2a810f500998
# Successfully built musixmatch-py
# ...
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# ...

# %%
pip install FFmpeg
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for FFmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6089 sha256=fbe230a000b1364ad12b5151fa3d321d5fcae691b7f28b2b3f51377be72dbd54
#   Stored in directory: c:\users\nisar\appdata\local\pip\cache\wheels\1d\57\24\4eff6a03a9ea0e647568e8a5a0546cdf957e3cf005372c0245
# Successfully built FFmpeg
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oundfile (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\nisar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -otobuf (c:\users\nisar\anaconda3\lib\site-packages)
# ...
